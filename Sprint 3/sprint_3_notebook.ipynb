# %% [markdown]
# <div>
# Olá, Fabrício!
#
# Meu nome é Luiz. Fico feliz em revisar seu projeto. Ao longo do texto farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Estarei aberto a feedbacks e discussões sobre o tema.
#
# **Peço que mantenha e não altere os comentários que eu fizer por aqui para que possamos nos localizar posteriormente, ok?**
#
# Mais uma coisa, vamos utilizar um código de cores para você entender o meu feedback no seu notebook. Funciona assim:
#
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo foi feito corretamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Alerta não crítico, mas que pode ser corrigido para melhoria geral no seu código/análise.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Erro que precisa ser arrumado, caso contrário seu projeto **não** será aceito.
# </div>
#
# Você pode interagir comigo através dessa célula:
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário geral do revisor v1</b> <a class="tocSkip"></a>
# <s>
# Obrigado por enviar o seu projeto e pelo esforço de chegar até aqui. O seu projeto possui alguns pontos bem interessantes, dos quais eu destaco:
#
# - Código bem simples e estruturado
# - Comentários sucintos e bem objetivos
# - Análises bem detalhadas em cada etapa do projeto
# - Boas habilidadades de manipulação de dados
#
# <br>
#
# Entretanto, deixei alguns comentários em alguns trechos que precisam de ajuste. Peço que trabalhe nesses pontos para avançarmos.
#
# <br>
#
# Qualquer dúvida, pode contar comigo.
#
# <br>
#
# **Até breve!**
# </s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor v2 </b> <a class="tocSkip"></a>
# <s>
# Obrigado por enviar o seu projeto e pelo esforço para executar as etapas necessárias.
# <br>
#
# Avançamos bastante com essa versão do seu trabalho, ficou muito boa! Entretanto, precisamos de pequenos ajustes para avançarmos. Deixei alguns comentários e sugestões para te ajudar com a sua solução. Espero que sejam úteis.
#
# <br>
#
# Se tiver alguma dúvida, pode contar comigo.
#
# <br>
#
# **Até breve!**
# </s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário geral do revisor v3</b> <a class="tocSkip"></a>
#
# Obrigado por enviar o seu projeto e fazer os ajustes sugeridos. Essa versão do seu trabalho ficou muito melhor! Espero que as sugestões sejam relevantes para projetos futuros.
#
# <br>
# Te desejo uma jornada de muito sucesso e aprendizado.
#
# <br>
#
# Qualquer dúvida, pode contar comigo.
#
# <br>
#
# **Até breve!**
#
# </div>

# %% [markdown]
# # Vamos encher o carrinho!

# %% [markdown]
# # Introdução
#
# A Instacart é uma plataforma de entrega de supermercado onde os clientes podem fazer um pedido de supermercado e receber a compra em casa, semelhante ao funcionamento do Uber Eats e do iFood. O conjunto de dados que fornecemos a você foi modificado do original. Reduzimos o tamanho do conjunto de dados para que seus cálculos sejam executados mais rapidamente e introduzimos valores ausentes e duplicados. Também tivemos o cuidado de preservar as distribuições dos dados originais quando fizemos as alterações.
#
# Você precisa completar três etapas. Para cada uma delas, escreva uma breve introdução descrevendo como você pretende concluir a etapa e justifique suas decisões em parágrafos explicativos intermédios a medida que você avança na solução. Escreva também uma conclusão para resumir suas conclusões e escolhas.

# %% [markdown]
# ## Dicionário de dados
#
# Há cinco tabelas no conjunto de dados, e você vai precisar usar todas elas para pré-processar os dados e fazer a AED. Abaixo está um dicionário que lista as colunas de cada tabela e descreve os dados contidos nelas.
#
# - `instacart_orders.csv`: cada linha corresponde a um pedido no aplicativo da Instacart
#     - `'order_id'`: é o número de identificação unívoco de cada pedido
#     - `'user_id'`: é o número de identificação unívoco da conta de cada cliente
#     - `'order_number'`: é o número de vezes que o cliente fez um pedido
#     - `'order_dow'`: é o dia da semana em que o pedido foi feito (0 é domingo)
#     - `'order_hour_of_day'`: é a hora do dia em que o pedido foi feito
#     - `'days_since_prior_order'`: é o número de dias desde que o cliente fez seu pedido anterior
#
#
#
#
# - `products.csv`: cada linha corresponde a um produto unívoco que os clientes podem comprar
#     - `'product_id'`: é o número de identificação unívoco de cada produto
#     - `'product_name'`: é o nome do produto
#     - `'aisle_id'`: é o número de identificação unívoco de cada categoria de seção do supermercado
#     - `'department_id'`: é o número de identificação unívoco de cada categoria de departamento do supermercado
#
#
#
#
# -	`order_products.csv`: cada linha corresponde a um item incluído em um pedido
#     -	`'order_id'`: é o número de identificação unívoco de cada pedido
#     -	`'product_id'`: é o número de identificação unívoco de cada produto
#     -	`'add_to_cart_order'`: é a ordem sequencial em que cada item foi colocado no carrinho
#     -	`'reordered'`: 0 se o cliente nunca comprou o produto antes, 1 se já o comprou
#
#
#
#
# -	`aisles.csv`
#     -	`'aisle_id'`: é o número de identificação unívoco de cada categoria de seção do supermercado
#     -	`'aisle'`: é o nome da seção
#
#
#
# -	`departments.csv`
#     -	`'department_id'`: é o número de identificação unívoco de cada categoria de departamento do supermercado
#     -	`'department'`: é o nome do departamento

# %% [markdown]
# # Etapa 1. Visão geral dos dados
#
# Leia os arquivos de dados (/datasets/instacart_orders.csv, /datasets/products.csv, /datasets/aisles.csv, /datasets/departments.csv e /datasets/order_products.csv) com `pd.read_csv()` usando os parâmetros apropriados para fazer isso corretamente. Verifique as informações para cada DataFrame criado.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Visão geral dos dados

# %% [markdown]
# Primeiramente, vamos importar as bibliotecas necessárias para fazer toda a análise dos dados, as quais consitem em pandas, para análise de dados em si, e matplotlib, para auxiliar na elaboração de gráficos. Em seguida, iremos recrutar os bancos de dados que deverão ser utilizados e checar suas informações para entender como eles são apresentados.

# %%
# Importe as bibliotecas
import pandas as pd
from matplotlib import pyplot as plt

# %%
# leia os conjuntos de dados em DataFrames

df_instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')

df_products = pd.read_csv('/datasets/products.csv', sep=';')

df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')

df_departments = pd.read_csv('/datasets/departments.csv', sep=';')

df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O conjunto de dados foi carregado corretamente usando o separador `;`.
# - O import das bibliotecas foi feito de forma correta e em uma célula separada.
# </div>

# %%
# imprima as informações sobre o DataFrame
df_instacart_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# imprima as informações sobre o DataFrame
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# imprima as informações sobre o DataFrame
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# imprima as informações sobre o DataFrame
df_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
# imprima as informações sobre o DataFrame
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Dica: Aqui você poderia usar o método `head()` ou `sample()` para exibir uma amostra inicial dos seus dados
# - O método `info()` foi utilizado para estudo inicial do conjunto de dados
#
# </div>

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 1. Visão geral dos dados
#
# É possível observar primeiramente que os arquivos csv estavam usando ponto e vírgula (;) como separador, por isso foi necessário adicionar o parâmetro "sep=';'" ao recrutar os dados nos arquivos. Além disso, é possível notar os seguintes pontos:
#
# - Alguns dados categóricos estão sendo representados como número inteiro. Um exemplo disso são as colunas que fornecem códigos e que tem o termo "id" na sua nomenclatura;
#
# - Há alguns nomes de produtos faltando na coluna "product_name" no dataframe "df_products", provavelmente por erro de cadastro;
#
# - Há valores nulos em agumas colunas, como "days_since_prior_order", "add_to_cart_order" e "reordered". O primeiro provavelmente pelo cliente só ter feito a compra uma vez, o segundo provavelmente devido ao cliente somente ter adicionado um item ao carrinho de compras online e o último provavelmente  por erro de cadastro.

# %% [markdown]
# # Etapa 2. Preparação de dados
#
# Faça o pré-processamento dos dados da seguinte maneira:
#
# -	Verifique e corrija os tipos de dados (por exemplo, certifique-se de que as colunas de ID sejam números inteiros)
# -	Identifique e preencha valores ausentes
# -	Identifique e remova valores duplicados
#
# Certifique-se de explicar que tipos de valores ausentes e duplicados você encontrou, como você os preencheu ou removeu, por que escolheu esses métodos e por que você acha que esses valores ausentes e duplicados estavam presentes no conjunto de dados.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Preparação de dados
#
# Segue planejamento para pré-processamento de dados:
# - Verificar e corrigir tipos de dados: usar métodos astype(), to_numeric() ou to_datetime();
# - Identificar e preencher valores ausentes: usar métodos isna() e fillna();
# - Identificar e remover valores duplicados: usar métodos duplicated() com sum() e drop_duplicates()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Boas observações!
#
# </div>

# %% [markdown]
# ## Encontre e remova valores duplicados (e descreva por que você está fazendo suas escolhas)

# %% [markdown]
# ### DataFrame `orders`

# %%
# Verificar se há pedidos duplicados
print(df_instacart_orders[df_instacart_orders.duplicated()].sort_values(by='order_id'))
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 371905    391768    57671            19          3                  2
# 321100    408114    68324             4          3                  2
# 394347    467134    63189            21          3                  2
# 145574    794638    50898            24          3                  2
# 311713   1021560    53767             3          3                  2
# 273805   1112182   202304            84          3                  2
# 411408   1286742   183220            48          3                  2
# 266232   1782114   106752             1          3                  2
# 230807   1918001   188546            14          3                  2
# 323900   1919531   191501            32          3                  2
# 441599   2125197    14050            48          3                  2
# 223105   2160484   107525            16          3                  2
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os valores duplicados para o dataset `orders` foram verificados
# - Seria útil imprimir a quantidade de valores duplicados
# </div>

# %% [markdown]
# Há linhas duplicadas? Se sim, o que elas têm em comum?
#
# Todos os pedidos duplicados foram feitos na quarta-feira às 2h da manhã.

# %%
# Com base nas suas conclusões,

# verifique todos os pedidos feitos às 2h da manhã nas quartas-feiras

df_instacart_orders[(df_instacart_orders['order_dow'] == 3) & (df_instacart_orders['order_hour_of_day'] == 2)].sort_values(by='order_id')
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 452265       191   176417            44          3                  2
# 468324    222962    54979            59          3                  2
# 247867    238782   196224             6          3                  2
# 417106    248760   204961            25          3                  2
# 328565    264348    34806             6          3                  2
# ...          ...      ...           ...        ...                ...
# 97378    3226444   149996             3          3                  2
# 416198   3275652   169225             7          3                  2
# 415975   3286161    77320             9          3                  2
# 457013   3384021    14881             6          3                  2
# 178465   3389820    21703             2          3                  2
#
#         days_since_prior_order
# 452265                     6.0
# 468324                     3.0
# ...

# %% [markdown]
# O que esse resultado quer dizer?
#
# Existem pedidos não duplicados e duplicados nas quartas-feiras as 2 da manhã. Isso significa que houve algum erro que provocou duplicação de pedidos e que esse erro está acontecendo as 2 da manhã na quarta-feira. É possível verificar também que os números de order_id não são sequenciais, o que pode significar que o erro aconteceu em diferentes quartas-feiras.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante verificou corretamente que pedidos duplicados ocorreram às 2:00 da manhã de Quarta-feira, o que pode sugerir um erro na geração dos dados.
# </div>

# %%
# Remova pedidos duplicados
df_instacart_orders = df_instacart_orders.drop_duplicates().reset_index(drop=True)

# %%
# Verifique as linhas duplicadas mais uma vez
print(df_instacart_orders.duplicated().sum())
# Out:
# 0

# %%
# Verifique novamente apenas os IDs de pedidos duplicados
print(df_instacart_orders['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Os códigos referentes a "order_id" foram devidamente excluidos. Isso significa que uma mesma compra não será mais encontrada em duplicidade no nosso banco de dados.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
# <s>
# Aqui você precisa resetar os índices do seu dataframe após a operação de remoção de duplicados para resetar os valores originais (`.reset_index(drop=True)`)
#
#
# ```python
# .drop_duplicates()
# ...
# .reset_index(drop=True)
# ...
# ```
# </s>
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# Acredito que agora está corrigido
# </div>

# %% [markdown]
# ### DataFrame `products`

# %%
# Verifique se há linhas completamente duplicadas

print(df_products.duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas se há IDs de departamentos duplicados

print(df_products['product_id'].duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas se há nomes de produtos duplicados (converta os nomes para minúsculas para uma comparação melhor)
df_products['product_name'] = df_products['product_name'].str.lower()
print(df_products['product_name'].duplicated().sum())
# Out:
# 1361

# %%
# Verifique os nomes de produtos duplicados que não estão faltando
print(df_products[df_products['product_name'].duplicated()].dropna(subset=['product_name']))
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  biotin 1000 mcg        47
# 5455         5456                 green tea with ginseng and honey        96
# 5558         5559                           cream of mushroom soup        69
# 7558         7559                        cinnamon rolls with icing       105
# 9037         9038                           american cheese slices        21
# ...           ...                                              ...       ...
# 49689       49690                    high performance energy drink        64
# 49690       49691                    original pancake & waffle mix       130
# 49691       49692  organic instant oatmeal light maple brown sugar       130
# 49692       49693                           spring water body wash       127
# 49693       49694                          burrito- steak & cheese        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Dos produtos com nomes duplicados, somente 104 não estão faltando.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
#
# - Os nomes dos produtos foram convertidos para `lowercase` para padronização
# - Os valores duplicados foram verificados
# - As conclusões intermediárias foram apresentadas
#
# </div>

# %% [markdown]
# ### DataFrame `departments`

# %%
# Verifique se há linhas completamente duplicadas
print(df_departments.duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
print(df_departments['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Somei a quantidade de duplicados que poderia existir no banco de dados. Como o retorno foi zero, isso significa que não há nem duplicados inteiros nem 'department_id' duplicados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os valores duplicados foram verificados
# - As conclusões intermediárias foram apresentadas
# </div>

# %% [markdown]
# ### DataFrame `aisles`

# %%
# Verifique se há linhas completamente duplicadas
print(df_aisles.duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
print(df_aisles['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Mesmo método aplicado e não há duplicados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os valores duplicados foram verificados
# - As conclusões intermediárias foram apresentadas
# </div>

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Verifique se há linhas completamente duplicadas
print(df_order_products.duplicated().sum())
# Out:
# 0

# %%
# Verifique mais uma vez se há outros casos complicados de duplicados
print(df_order_products['order_id'].duplicated().sum()) #quantidade de ordens de compra duplicadas
print()
print(df_order_products[['order_id', 'product_id']].duplicated().sum()) #quantidade de ordens de compras duplicadas com mesmos produtos
# Out:
# 4094961
#
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Não linhas completamente duplicadas, porém há um grande número de 'order_id' duplicados. No entanto isso pode ser considerado normal uma vez que diferentes itens podem ser adicionados a uma só ordem de compra. A prova disso é que não há duplicados quando se testa duplicidade de 'order_id' com 'product_id'.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os valores duplicados foram verificados usando o subconjunto `order_id`, `product_id`
# - As conclusões intermediárias foram apresentadas
# </div>

# %% [markdown]
# ## Encontre e remova valores ausentes
#
#
# Ao processarmos valores duplicados, observamos que também temos valores ausentes que precisamos investigar nas seguintes colunas:
#
# *	A coluna `'product_name'` da tabela products.
# *	A coluna `'days_since_prior_order'` da tabela orders.
# *	A coluna `'add_to_cart_order'` da tabela order_products.

# %% [markdown]
# ### DataFrame `products`

# %%
# Encontre valores ausentes na coluna 'product_name'
df_products[df_products['product_name'].isna()]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Aparentemente todos os produtos com nomes ausentes estão associados ao corredor (aisle_id) 100 e ao departamento (department_id) 21.

# %%
# Todos os nomes de produtos ausentes estão associados com a seção de ID 100?
print(df_products[(df_products['product_name'].isna()) & (df_products['aisle_id'] == 100)])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Sim. Todos os produtos com nomes ausentes estão associados com a seção de ID 100.

# %%
# Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?

print(df_products[(df_products['product_name'].isna()) & (df_products['department_id'] == 21)])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Sim. Todos os produtos com nomes ausentes estão associados com o departamento de ID 21.

# %%
# Use as tabelas de departamentos e seções para verificar os dados da seção ID 100 e do departamento ID 21.

print(df_aisles[df_aisles['aisle_id'] == 100])
print()
print(df_departments[df_departments['department_id'] == 21])
# Out:
#     aisle_id    aisle
# 99       100  missing
#
#     department_id department
# 20             21    missing

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Aparentemente, o departament 21 e a seção 100 são designados a produtos que estão em falta.

# %%
# Preencha nomes de produtos ausentes com 'Unknown'

df_products['product_name'] = df_products['product_name'].fillna('Unknown') # Os nomes dos

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Ao verificar os nomes dos produtos ausentes na tabela 'df_products' identificou-se que tais produtos tem o departamento 21 e a seção 100 em comum. Assim, verificando na base de dados de 'df_aisles' e em 'df_departments', verificamos que tais departamento e seção são designados a itens faltantes. Por esse motivo, foi possível atribuir a palavra "Unknown" como nome desses produtos sem prejudicar a análise de dados.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>- Aqui você precisa preencher o nome dos produtos com `Unknown`.</s>
# </div>
#
# Você pode interagir comigo através dessa célula:
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - O preenchimento com `Unknown` não foi feito com esse código: `df_products['product_id'] = df_products['product_id'].fillna('Unknown')` ?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# <s>Perceba que você está preenchendo o atributo `product_id` e não `product_name`. O correto deve ser o atributo `product_name`</s>
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - Agora entendi! Obrigado!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - A verificação de que os produtos com nomes vazios estão associados com o `departamento==21` e `aisle==100` foi realizada.
# </div>

# %% [markdown]
# ### DataFrame `orders`

# %%
# Encontre os valores ausentes
df_instacart_orders.isna().sum()
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?
print(df_instacart_orders[(df_instacart_orders['days_since_prior_order'].isna()) & (df_instacart_orders['order_number'] > 1)])
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Todos os valores ausentes da tabela estão associados a coluna 'days_since_prior_order' e a clientes que não compraram mais de uma vez. Isso significa que os valores ausentes representam somente clientes que ainda não voltaram a comprar novamente.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante apresentou as observações sobre o atributo `days_since_prior_order`.
# </div>

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Encontre os valores ausentes
df_order_products.isna().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# Quais são os valores mínimo e máximo dessa coluna?
print(df_order_products['add_to_cart_order'].min())
print()
print(df_order_products['add_to_cart_order'].max())
# Out:
# 1.0
#
# 64.0

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Há somente valores ausentes na coluna 'add_to_cart_order'. A mesma coluna tem 1 como valor mínimo e 64 como o máximo. Isso significa que clientes compraram, no máximo, 64 itens de uma só vez.

# %%
# Salve todos os IDs dos pedidos com pelo menos um valor ausente em 'add_to_cart_order'

list_of_ids = df_order_products[df_order_products['add_to_cart_order'].isnull()]['order_id'].unique()
print(list_of_ids)
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# Todos os pedidos com valores ausentes contêm mais de 64 produtos?
# Agrupe os pedidos com dados ausentes por ID de pedido
null_product_data = df_order_products[df_order_products['add_to_cart_order'].isnull()].groupby(by='order_id')

# Conte o número de 'product_id' em cada pedido e verifique o valor mínimo da contagem
print(null_product_data['product_id'].count())
print()
print('Valor mínimo:', null_product_data['product_id'].count().min())
print('Valor máximo:', null_product_data['product_id'].count().max())
# Out:
# order_id
# 9310        1
# 61355      63
# 102236     31
# 129627      5
# 165801      6
#            ..
# 2999801     6
# 3125735    22
# 3308010    51
# 3347453     7
# 3383594     5
# Name: product_id, Length: 70, dtype: int64
#
# Valor mínimo: 1
# Valor máximo: 63

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Todos os pedidos com dados ausentes não contém mais de 64 produtos e apresentam valor mínimo de 1 produto.

# %%
# Substitua valores ausentes na coluna 'add_to_cart_order' por 999 e converta a coluna para o tipo integer

df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999).astype(int)

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Como o valor mínimo de produtos em pedidos que não há a informação sobre ordem de adição ao carrinho é 1 e não 0, isso significa que não há tal informações quando os pedidos tem menos de 64 produtos. Isso pode ter acontecido por um erro ou caso todos os produtos fossem adicionados ao carrinho de uma só vez. Para padronar a coluna para números inteiros, foi interido o valor 999, que vai passar a significar valor ausente.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os métodos `min()` e `max()` foram utilizados para contar a quantidade mínima e máxima de produtos adicionados ao carrinho
# - Os valores ausentes do atributo `add_to_cart_order` foram preenchidos
# - As conclusões intermediárias foram apresentadas
# </div>

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 2. Preparação de dados
#
# Valores duplicados e ausentes foram, primeiramente, compreendidos para depois decidir qual atitude seria mais adequada para lidar com eles e tratar os dados.

# %% [markdown]
# # Etapa 3. Análise de dados
#
# Quando os dados estiverem processados ​​e prontos, execute a seguinte análise:

# %% [markdown]
# # [A] Fácil (é necessário concluir tudo para passar)
#
# 1.	Verifique se os valores nas colunas `'order_hour_of_day'` e `'order_dow'` na tabela `orders` fazem sentido (ou seja, os valores da coluna  `'order_hour_of_day'` variam de 0 a 23 e os da `'order_dow'` variam de 0 a 6).
# 2.	Crie um gráfico que mostre quantas pessoas fazem pedidos por cada hora do dia.
# 3.	Crie um gráfico que mostre em que dia da semana as pessoas fazem compras.
# 4.	Crie um gráfico que mostre quanto tempo as pessoas esperam até fazer seu próximo pedido e comente sobre os valores mínimo e máximo.

# %% [markdown]
# ### [A1] Verifique se os valores fazem sentido

# %%
df_instacart_orders['order_hour_of_day'].unique()
# Out:
# array([13, 12, 19, 20, 11,  8, 18, 15, 16,  9, 22, 10,  0, 14, 17,  1,  7,
#         6,  2, 21,  3, 23,  5,  4])

# %%
df_instacart_orders['order_dow'].unique()
# Out:
# array([6, 5, 0, 4, 3, 1, 2])

# %% [markdown]
# Escreva suas conclusões aqui
#
# Os valores na tabelas 'order_hour_of_day' e 'order_dow' fazem sentido.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Correto. Outras sugestões:
# - verificar o intervalo das horas do dia
# - usar o método `.value_counts()`
# - plotar a distribuição dessa variável
# </div>

# %% [markdown]
# ### [A2] Quantas pessoas fazem pedidos a cada hora do dia?

# %%
df_instacart_orders[['order_id', 'user_id', 'order_hour_of_day', 'order_dow']] = df_instacart_orders[['order_id', 'user_id','order_hour_of_day', 'order_dow']].astype('category')
df_grouped_hours = df_instacart_orders.groupby(by='order_hour_of_day', as_index=False).count()

df_grouped_hours.plot(kind='bar', 
                      x='order_hour_of_day', 
                      y='order_id', 
                      title='Orders per hour of the day', 
                      xlabel='Hour of the day', 
                      ylabel='Number of orders', 
                      rot=0, 
                      legend=False)
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# As pessoas costumam fazer mais compras as 10h da manhã. Entre as 9h da manhã e as 16h, as pessoas fazem a maior quantidade de pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante analisou a distribuição de compras por hora do dia
# - As conclusões foram apresentadas
# </div>

# %% [markdown]
# ### [A3] Em que dia da semana as pessoas fazem compras?

# %%
df_grouped_days = df_instacart_orders.groupby(by='order_dow', as_index=False).count()

df_grouped_days.plot(kind='bar', 
                      x='order_dow', 
                      y='order_id', 
                      title='Orders per day', 
                      xlabel='Days of the week', 
                      ylabel='Number of orders',
                      rot=0,  
                      legend=False)

weekdays = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

plt.xticks(df_grouped_days['order_dow'], weekdays)
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# As pessoas fazem mais compras aos domingos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante analisou a distribuição de compras por dia da semana
# - As conclusões foram apresentadas
# </div>

# %% [markdown]
# ### [A4] Quanto tempo as pessoas esperam até fazer outro pedido?

# %% [markdown]
# Escreva suas conclusões aqui
#
# A maioria das pessoas esperam em torno de 30 dias para fazer a próxima compra, mas isso pode ser alguma limitação de cadastro do sistema da empresa.

# %%
df_instacart_orders.groupby(by='days_since_prior_order')['user_id'].count().plot(kind='bar')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa plotar um gráfico de barras com os dados acima e analisar a distribuição dos dados</s>
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - O histograma e o gráfico de barras não teria o mesmo resultado? Por que o gráfico de barras seria melhor que o histograma nesse caso? Havia feito o histograma com bins=30 para coincidir com os dias do mês. Fiz os dois para comparação.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# Nesse caso, os resultados são bem parecidos, mas isso não é garantido, pois o histograma pode agrupar os dados de formas diferentes a depender da distribuição e regiões de concentração de dados. Gráficos de barras são geralmente usados para apresentar variáveis categóricas ou discretas, enquanto histogramas são indicados para analisar a distribuição de uma variável.
#
# <br>
#
# Referência: https://venngage.com/blog/bar-charts-vs-histograms/#:~:text=Although%20histograms%20and%20bar%20charts,of%20variables%20in%20a%20dataset.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - Compreendido e ajustado! Obrigado!
# </div>

# %% [markdown]
# # [B] Médio (é necessário concluir tudo para passar)
#
# 1.	Há alguma diferença nas distribuições de `'order_hour_of_day'` nas quartas e sábados? Construa gráficos de barras para ambos os dias no mesmo gráfico e descreva as diferenças que você notou.
# 2.	Construa um gráfico de distribuição para o número de pedidos que os clientes fazem (ou seja, quantos clientes fizeram apenas 1 pedido, quantos fizeram apenas 2, quantos apenas 3, etc.)
# 3.	Quais são os 20 produtos comprados com mais frequência? Exiba os IDs e nomes.

# %% [markdown]
# ### [B1] Diferenças nas quartas e sábados em `'order_hour_of_day'`. Crie gráficos de barras para ambos os dias e descreva as diferenças.

# %%
wed_orders = df_instacart_orders[df_instacart_orders['order_dow'] == 3].groupby(by='order_hour_of_day')['order_id'].count()

# %%
sat_orders = df_instacart_orders[df_instacart_orders['order_dow'] == 6].groupby(by='order_hour_of_day')['order_id'].count()

# %%
wed_orders.plot(kind='bar', 
                x='order_hour_of_day', 
                y='order_id',
                title='Orders per hours on Wednesdays', 
                xlabel='hour of a day',
                ylabel='Number of orders',
                rot=0)


plt.show()

# %%
sat_orders.plot(kind='bar', 
                x='order_hour_of_day', 
                y='order_id',
                title='Orders per hours on Saturdays', 
                xlabel='hour of a day',
                ylabel='Number of orders',
                rot=0)
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# Há uma diferença sutil de quantidade de ordens de compra nas quartas e sábados quando se observa os horários. Entre 12h e 14h, as pessoas compram menos nas quartas em comparação aos sábados.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante comparou as distribuições de pedidos feitos na Quarta e ao Sábado. Dica: aqui você poderia plotar as distribuições na mesma figura ou lado a lado usando subplots
# - As conclusões foram apresentadas
# </div>

# %% [markdown]
# ### [B2] Qual é a distribuição do número de pedidos por cliente?

# %%
df_grouped_orders = df_instacart_orders.groupby(by='user_id')['order_id'].count().reset_index()

# %%
df_grouped_orders['order_id'].plot(kind='hist',
                                   bins=28,
                                   xlim=1,
                                   title='Number of orders per users'
                                  )
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# A maioria dos clientes faz somente uma compra.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante analisou a distribuição do número de pedidos por cliente. Sugestão: aqui você poderia ter analisado faixas mais amplas do gráfico acima, não somente o valor máximo mas também regiões de grande concentração (1-5 pedidos, por exemplo)
# - As conclusões foram apresentadas
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - De fato. Até pensei em fazer isso quando estava escrevendo o código, mas achei que dessa forma o gráfico também mostratia que a calda direita da curva é longa e achei que isso também poderia ser importante mostrar. Agradeço a sugestão.
# </div>

# %% [markdown]
# ### [B3] Quais são os 20 produtos mais populares? Exiba os IDs e nomes.

# %%
df_pop_products = df_order_products.groupby(by='product_id', as_index=False)['order_id'].count().sort_values('order_id', ascending=False).reset_index(drop=True).head(20)
df_pop_products.rename(columns={'order_id': 'order_count'}, inplace=True)

# %%
df_pop_merged = pd.merge(df_pop_products, df_products[['product_id', 'product_name']], on='product_id')
df_pop_merged = df_pop_merged[['product_id', 'product_name', 'order_count']]

# %%
df_pop_merged
# Out:
#     product_id              product_name  order_count
# 0        24852                    banana        66050
# 1        13176    bag of organic bananas        53297
# 2        21137      organic strawberries        37039
# 3        21903      organic baby spinach        33971
# 4        47209      organic hass avocado        29773
# 5        47766           organic avocado        24689
# 6        47626               large lemon        21495
# 7        16797              strawberries        20018
# 8        26209                     limes        19690
# 9        27845        organic whole milk        19600
# 10       27966       organic raspberries        19197
# 11       22935      organic yellow onion        15898
# 12       24964            organic garlic        15292
# 13       45007          organic zucchini        14584
# 14       39275       organic blueberries        13879
# 15       49683            cucumber kirby        13675
# ...

# %% [markdown]
# Escreva suas conclusões aqui
#
# Banana é o produto mais vendido.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante analisou a distribuição dos produtos mais populares. Bom trabalho com o `merge` entre as tabelas
# - As conclusões foram apresentadas
# </div>

# %% [markdown]
# # [C] Difícil (é necessário concluir pelo menos duas perguntas para passar)
#
# 1.	Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?
# 2.	Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.
# 3.	Para cada produto, qual parcela de seus pedidos são repetidos? Crie uma tabela com colunas de ID e nome do produto e a proporção de pedidos repetidos.
# 4.	Para cada cliente, qual proporção de todos os seus pedidos são repetidos?
# 5.	Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros? Exiba o ID do produto, nome e o número de vezes que ele foi o primeiro a ser adicionado a um carrinho.

# %% [markdown]
# ### [C1] Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?

# %%
# Primeiramente, vou usar groupby() para saber a quantidade de produtos por ordem de pedido.

df_products_in_order = df_order_products.groupby('order_id')['product_id'].count()

# %%
# Agora vou entender como está a distribuição dos pedidos para saber se devo usar a média ou a mediana como parâmetro

df_products_in_order.plot(kind='hist', bins=30)
plt.show()

# %%
# Para melhorar a visualização do gráfico, vou fazer uma filtração e tentar plotar uma região próxima ao pico da dispersão.

df_products_in_order[df_products_in_order < 30].plot(kind='hist',bins=20)
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# De acordo com informações da dispersão, as pessoas normalmente compram 5 itens em cada pedido.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>- Aqui você precisa plotar um histograma ou gráfico de barras para exibir a forma da distribuição dos dados
# - Ao plotar a distribuição, verifique se faz sentido filtrar a região mais concentrada nos dados para evitar que o gráfico fique muito carregado (< ~35 pedidos) conforme você fez acima
# </s>
#
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - Desculpe, mas não entendi o erro. Pensei ter feito exatamente o que pede para eu fazer na correção. Poderia me explicar melhor?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# <s>Você só precisa usar um histograma ao invés do gráfico de barras. Veja a justificativa que deixei na seção anterior sobre isso</s>
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# - Agora acredito que está ok. Obrigado.
# </div>

# %% [markdown]
# ### [C2] Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.

# %%
# Primeiramente, preciso filtrar somente pedidos repetidos: 'reordered' = 1
df_repeated_orders = df_order_products[df_order_products['reordered'] == 1]
print(df_repeated_orders)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 1          567889        1560                  1          1
# 2         2261212       26683                  1          1
# 3          491251        8670                 35          1
# 4         2571142        1940                  5          1
# 5         2456893       21616                  4          1
# ...           ...         ...                ...        ...
# 4544999   1622300       24852                  1          1
# 4545000   1125324       40600                  6          1
# 4545002    577211       15290                 12          1
# 4545004    692640       47766                  4          1
# 4545005    319435         691                  8          1
#
# [2683838 rows x 4 columns]

# %%
# Agora preciso ordenar os pedidos e descobrir os 20 principais mais pedidos entre pedidos repetidos.
df_pop_repeated = df_repeated_orders.groupby(by='product_id')['order_id'].count().sort_values(ascending=False).head(20).reset_index()
df_pop_repeated.rename(columns={'order_id': 'order_count'}, inplace=True)

# %%
# Próxima etapa é juntar tabelas para conhecer os nomes dos produtos
df_pop_repeated_names = pd.merge(df_pop_repeated, df_products[['product_id', 'product_name']], on='product_id')
df_pop_repeated_names = df_pop_repeated_names[['product_id', 'product_name', 'order_count']]

# %%
df_pop_repeated_names
# Out:
#     product_id              product_name  order_count
# 0        24852                    banana        55763
# 1        13176    bag of organic bananas        44450
# 2        21137      organic strawberries        28639
# 3        21903      organic baby spinach        26233
# 4        47209      organic hass avocado        23629
# 5        47766           organic avocado        18743
# 6        27845        organic whole milk        16251
# 7        47626               large lemon        15044
# 8        27966       organic raspberries        14748
# 9        16797              strawberries        13945
# 10       26209                     limes        13327
# 11       22935      organic yellow onion        11145
# 12       24964            organic garlic        10411
# 13       45007          organic zucchini        10076
# 14       49683            cucumber kirby         9538
# 15       28204        organic fuji apple         8989
# ...

# %% [markdown]
# Escreva suas conclusões aqui
#
# O item mais frequentemente pedido a partir da segunda compra é banana.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os produtos mais frequentemente incluídos em pedidos repetidos foram analisados
# - As observações foram apresentadas
# </div>

# %% [markdown]
# ### [C3] Para cada produto, qual parcela de todos os pedidos dele são repetidos?

# %% [markdown]
# Escreva suas conclusões aqui

# %% [markdown]
# ### [C4] Para cada cliente, qual proporção de todos os seus pedidos são repetidos?

# %% [markdown]
# Escreva suas conclusões aqui

# %% [markdown]
# ### [C5] Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros?

# %% [markdown]
# Escreva suas conclusões aqui

# %% [markdown]
# # Conclusão geral do projeto:

# %% [markdown]
# - Entre as 9h da manhã e as 16h, as pessoas fazem a maior quantidade de pedidos.
# - As pessoas fazem mais compras aos domingos.
# - A maioria das pessoas esperam em torno de 30 dias para fazer a próxima compra, mas isso pode ser alguma limitação de cadastro do sistema da empresa. É necessário verificar esta informação junto a empresa Instacart.
# - Há uma diferença sutil de quantidade de ordens de compra nas quartas e sábados quando se observa os horários. Entre 12h e 14h, as pessoas compram menos nas quartas em comparação aos sábados.
# - A maioria dos clientes faz somente uma compra, porém a maioria compra 5 itens.
# - Banana é o produto mais vendido de maneira geral e também é o produto mais frequentemente vendido a partir da segunda compra.
# -

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Bom trabalho com a conclusão geral! Dica: aqui você poderia resumir brevemente a etapa de preparação dos dados.
# </div>
